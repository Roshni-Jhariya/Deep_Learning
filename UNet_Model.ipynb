# %% [markdown]
# ## Importing the Libraries

# %%
from keras.models import Model, Sequential
from keras.layers import Activation, Dense, BatchNormalization, concatenate, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from keras.callbacks import EarlyStopping
from keras.layers.core import SpatialDropout2D
from keras import backend as K
from keras.optimizers import Adam
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from warnings import filterwarnings

filterwarnings('ignore')
np.random.seed(101)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# Defining a function to load the data in sorted order

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
def binary(img):
    ret, img = cv2.threshold (img, 127, 255, cv2.THRESH_BINARY)
    img = np.array (img, dtype=np.uint8)
    mask = np.zeros((img.shape[0],img.shape[1]),dtype=np.uint8)*255
    img = cv2.bitwise_xor(img,mask)
    img = img//255
    img = np.reshape(img,(img.shape[0],img.shape[1]))
    img = np.array(img,dtype=np.uint8)
    
    return img

# %%
y_train1=[]

for i in sorted(glob.glob('./Dataset224/y_train/*.bmp'), key=numericalSort):
    img = cv2.imread(i) # Read image here
    img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    img=cv2.resize(img,(224,224))
    
    #out = cv2.normalize(img.astype('double'), None, 0.0, 1.0, cv2.NORM_MINMAX) # Convert to normalized floating point
    out=binary(img)
    #out.save()
    y_train1.append(out)

# %%
x_train1=[]

for i in sorted(glob.glob('./Dataset224/x_train/*.jpg'), key=numericalSort):
    img = cv2.imread(i) # Read image here
    #out = cv2.normalize(img.astype('double'), None, 0.0, 1.0, cv2.NORM_MINMAX) # Convert to normalized floating point
    #out.save()
    x_train1.append(img)

# %%
x_test=[]

for i in sorted(glob.glob('./Dataset224/x_test/*.jpg'), key=numericalSort):
    img = cv2.imread(i) # Read image here
    #out = cv2.normalize(img.astype('double'), None, 0.0, 1.0, cv2.NORM_MINMAX) # Convert to normalized floating point
    #out.save()
    x_test.append(img)
    
    
x_test=np.array(x_test)

# %%
y_test=[]

for i in sorted(glob.glob('./Dataset224/y_test/*.png'), key=numericalSort):
    img = cv2.imread(i) # Read image here
    img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    img=cv2.resize(img,(224,224))
    
    #out = cv2.normalize(img.astype('double'), None, 0.0, 1.0, cv2.NORM_MINMAX) # Convert to normalized floating point
    out=binary(img)
    #out.save()
    y_test.append(out)
    
    
    
y_test=np.array(y_test)

# %% [markdown]
# Splitting the dataset into training set and test set to verify our model performance without any bias.

# %% [markdown]
# Let's plot an image to see how the original images look.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(x_train1[0])
plt.subplot(2,4,2)
plt.imshow(x_train1[3])
plt.subplot(2,4,3)
plt.imshow(x_train1[54])
plt.subplot(2,4,4)
plt.imshow(x_train1[77])
plt.subplot(2,4,5)
plt.imshow(x_train1[100])
plt.subplot(2,4,6)
plt.imshow(x_train1[125])
plt.subplot(2,4,7)
plt.imshow(x_train1[130])
plt.subplot(2,4,8)
plt.imshow(x_train1[149])
plt.show()

# %% [markdown]
# Now let's see their corresponding masks.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(y_train1[0], cmap = plt.cm.binary_r)
plt.subplot(2,4,2)
plt.imshow(y_train1[3], cmap = plt.cm.binary_r)
plt.subplot(2,4,3)
plt.imshow(y_train1[54], cmap = plt.cm.binary_r)
plt.subplot(2,4,4)
plt.imshow(y_train1[77], cmap = plt.cm.binary_r)
plt.subplot(2,4,5)
plt.imshow(y_train1[100], cmap = plt.cm.binary_r)
plt.subplot(2,4,6)
plt.imshow(y_train1[125], cmap = plt.cm.binary_r)
plt.subplot(2,4,7)
plt.imshow(y_train1[130], cmap = plt.cm.binary_r)
plt.subplot(2,4,8)
plt.imshow(y_train1[149], cmap = plt.cm.binary_r)
plt.show()

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train1, y_train1, test_size = 0.20, train_size=0.80,random_state = 101)

# %% [markdown]
# ## Defining the Loss Function

# %% [markdown]
# #### Jaccard Distance
# The Jaccard distance, which measures dissimilarity between sample sets, is complementary to the Jaccard coefficient and is obtained by subtracting the Jaccard coefficient from 1, or, equivalently, by dividing the difference of the sizes of the union and the intersection of two sets by the size of the union:

# %% [markdown]
# ![jd](https://www.geeksforgeeks.org/wp-content/ql-cache/quicklatex.com-44046533fcd54e98cb53619b3390e083_l3.svg)

# %% [markdown]
# ## Defining Evaluation Metrics

# %% [markdown]
# #### Intersection over Union
# The Jaccard index, also known as Intersection over Union and the Jaccard similarity coefficient is a statistic used for gauging the similarity and diversity of sample sets. The Jaccard coefficient measures similarity between finite sample sets, and is defined as the size of the intersection divided by the size of the union of the sample sets:

# %% [markdown]
# ![iou](https://www.d2l.ai/_images/iou.svg)

# %% [markdown]
# #### Dice coefficient
# The Dice score is not only a measure of how many positives you find, but it also penalizes for the false positives that the method finds, similar to precision. so it is more similar to precision than accuracy.

# %% [markdown]
# ![dc](https://cdn-images-1.medium.com/max/1600/1*Z1hkDvyhFBogT9EkzVkX2A.png)

# %% [markdown]
# #### Precision
# Precision is a good measure to determine, when the costs of False Positive is high.

# %% [markdown]
# ![precsion](https://wikimedia.org/api/rest_v1/media/math/render/svg/26106935459abe7c266f7b1ebfa2a824b334c807)

# %% [markdown]
# #### Recall
# Recall actually calculates how many of the Actual Positives our model capture through labeling it as Positive (True Positive). Applying the same understanding, we know that Recall shall be the model metric we use to select our best model when there is a high cost associated with False Negative.

# %% [markdown]
# ![recall](https://wikimedia.org/api/rest_v1/media/math/render/svg/4c233366865312bc99c832d1475e152c5074891b)

# %% [markdown]
# #### Accuracy

# %%
def iou(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(K.abs(y_true_f * y_pred_f))
    union = K.sum(y_true_f)+K.sum(y_pred_f)-intersection
    iou = K.mean((intersection + smooth) / (union + smooth))
    return iou

def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f)
    dice = K.mean((2. * intersection + smooth)/(union + smooth))
    return dice



def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %% [markdown]
# ## Image Augmentation
# To build a powerful image classifier using very little training data, image augmentation is usually required to boost the performance of deep networks. Image augmentation artificially creates training images through different ways of processing or combination of multiple processing, such as random rotation, shifts, shear and flips, etc.

# %% [markdown]
# We are going to define to methods for augmentation, one for **random rotation** and one for **horizontal flipping**

# %%
def random_rotation(x_image, y_image):
    rows_x,cols_x, chl_x = x_image.shape
    rows_y,cols_y = y_image.shape
    rand_num = np.random.randint(-40,40)
    M1 = cv2.getRotationMatrix2D((cols_x/2,rows_x/2),rand_num,1)
    M2 = cv2.getRotationMatrix2D((cols_y/2,rows_y/2),rand_num,1)
    x_image = cv2.warpAffine(x_image,M1,(cols_x,rows_x))
    y_image = cv2.warpAffine(y_image.astype('float32'),M2,(cols_y,rows_y))
    return x_image, y_image.astype('int')

def horizontal_flip(x_image, y_image):
    x_image = cv2.flip(x_image, 1)
    y_image = cv2.flip(y_image.astype('float32'), 1)
    return x_image, y_image.astype('int')

# %%
def img_augmentation(x_train, y_train):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    for idx in range(len(x_train)):
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        x,y = horizontal_flip(x_train[idx], y_train[idx])
        x_flip.append(x)
        y_flip.append(y)
    return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %% [markdown]
# calling the functions for the training data.

# %%
x_rotated, y_rotated, x_flipped, y_flipped = img_augmentation(x_train, y_train)

# %% [markdown]
# Let us have a look at our transformations.

# %%
img_num = 7
plt.figure(figsize=(12,12))
plt.subplot(3,2,1)
plt.imshow(x_train[img_num])
plt.title('Original Image')
plt.subplot(3,2,2)
plt.imshow(y_train[img_num], plt.cm.binary_r)
plt.title('Original Mask')
plt.subplot(3,2,3)
plt.imshow(x_rotated[img_num])
plt.title('Rotated Image')
plt.subplot(3,2,4)
plt.imshow(y_rotated[img_num], plt.cm.binary_r)
plt.title('Rotated Mask')
plt.subplot(3,2,5)
plt.imshow(x_flipped[img_num])
plt.title('Flipped Image')
plt.subplot(3,2,6)
plt.imshow(y_flipped[img_num], plt.cm.binary_r)
plt.title('Flipped Mask')
plt.show()

# %% [markdown]
# Now we join all the augmentations image arrays to the original training arrays.

# %%
x_train_full = np.concatenate([x_train, x_rotated, x_flipped])
y_train_full = np.concatenate([y_train, y_rotated, y_flipped])

# %%
x_train1=np.array(x_train_full)
y_train1=np.array(y_train_full)
x_val=np.array(x_val)
y_val=np.array(y_val)

# %% [markdown]
# #### Making a Validation Set
# We will split our full training set into train and validation set.
# Validation dataset is used to validate the performance after each epoch.

# %%
print(x_train1.shape)
print(y_train1.shape)
print(x_val.shape)
print(y_val.shape)
# Out:
# (2160, 224, 224, 3)
# (2160, 224, 224)
# (180, 224, 224, 3)
# (180, 224, 224)

# %%
print("Length of the Training Set   : {}".format(len(x_train1)))
print("Length of the Test Set       : {}".format(len(x_test)))
print("Length of the Validation Set : {}".format(len(x_val)))
# Out:
# Length of the Training Set   : 2160
# Length of the Test Set       : 379
# Length of the Validation Set : 180

# %% [markdown]
# ## The Model

# %% [markdown]
# Defining the model in a function which takes two arguments when called
# * **epoch_num**: number of epochs to run
# * **savename**: the name of the model for saving after training

# %% [markdown]
# #### Optimizer and Learning Rate
# * We adopt adam optimization algorithm or adaptive moments, to adjust the learning rate.
# * It is well known that learning rate is one of the critical hyperparameters that have a signiﬁcant impact on classiﬁcation performance.
# * Advantages of Adam optimizer are:
#     - Relatively low memory requirements (though higher than gradient descent and gradient descent with momentum).
#     - Usually works well even with a little tuning of hyperparameter
# * Adam is fairly robust to the choice of hyperparameters, and set the learning rate **α** as 0.003 to speed up the training procedure in this study as advised in the paper [here](https://arxiv.org/pdf/1703.05165v2.pdf)

# %% [markdown]
# ### Model Function

# %% [markdown]
# > ![arch](https://raw.githubusercontent.com/hashbanger/Skin_Lesion_Segmentation/master/graphics/unet_arch.png)

# %%
# Number of image channels (for example 3 in case of RGB, or 1 for grayscale images)
I_C = 3
# Number of output masks (1 in case you predict only one type of objects)
O_C = 1
# Pretrained weights

# %%
def double_conv_layer(x, size, dropout=0.40, batch_norm=True):
    #if K.image_dim_ordering() == 'th':
    if K.common.image_dim_ordering() == 'th':
        axis = 1
    else:
         axis = 3
    conv = Conv2D(size, (3, 3), padding='same')(x)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = Conv2D(size, (3, 3), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    if dropout > 0:
        conv = SpatialDropout2D(dropout)(conv)
    return conv


def UNET_224(epochs_num, savename):
    dropout_val=0.50
    #if K.image_dim_ordering() == 'th':
    if K.common.image_dim_ordering() == 'th':
        inputs = Input((I_C,224, 224))
        #inputs = Input((INPUT_CHANNELS, 320, 320))
        axis = 1
    else:
        inputs = Input((224, 224,I_C))
       #inputs = Input((320, 320, INPUT_CHANNELS))
        axis = 3
    filters = 32

    conv_224 = double_conv_layer(inputs, filters)
    pool_112 = MaxPooling2D(pool_size=(2, 2))(conv_224)

    conv_112 = double_conv_layer(pool_112, 2*filters)
    pool_56 = MaxPooling2D(pool_size=(2, 2))(conv_112)

    conv_56 = double_conv_layer(pool_56, 4*filters)
    pool_28 = MaxPooling2D(pool_size=(2, 2))(conv_56)

    conv_28 = double_conv_layer(pool_28, 8*filters)
    pool_14 = MaxPooling2D(pool_size=(2, 2))(conv_28)

    conv_14 = double_conv_layer(pool_14, 16*filters)
    pool_7 = MaxPooling2D(pool_size=(2, 2))(conv_14)

    conv_7 = double_conv_layer(pool_7, 32*filters)

    up_14 = concatenate([UpSampling2D(size=(2, 2))(conv_7), conv_14], axis=axis)
    up_conv_14 = double_conv_layer(up_14, 16*filters)

    up_28 = concatenate([UpSampling2D(size=(2, 2))(up_conv_14), conv_28], axis=axis)
    up_conv_28 = double_conv_layer(up_28, 8*filters)

    up_56 = concatenate([UpSampling2D(size=(2, 2))(up_conv_28), conv_56], axis=axis)
    up_conv_56 = double_conv_layer(up_56, 4*filters)

    up_112 = concatenate([UpSampling2D(size=(2, 2))(up_conv_56), conv_112], axis=axis)
    up_conv_112 = double_conv_layer(up_112, 2*filters)

    up_224 = concatenate([UpSampling2D(size=(2, 2))(up_conv_112), conv_224], axis=axis)
    up_conv_224 = double_conv_layer(up_224, filters, dropout_val)

    conv_final = Conv2D(O_C, (1, 1))(up_conv_224)
    conv_final = Activation('sigmoid')(conv_final)
    pred = Reshape((224,224))(conv_final)
    #pred = Reshape((320,320))(conv_final)
    model = Model(inputs, pred, name="UNET_224")
    model.compile(optimizer= Adam(lr = 0.003), loss= ['binary_crossentropy']
                  , metrics=[iou, dice_coef,recall, precision, accuracy])
    #model.summary()
    #hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 18,validation_data=(x_val, y_val), verbose=1)
    hist = model.fit(x_train1, y_train1, batch_size= 5, epochs= epochs_num,validation_data=(x_val, y_val), verbose=2)
    model.save(savename)
    return model, hist

# %%
model, hist = UNET_224(5, 'unet_5_epoch.h5')
# Out:
# Train on 2160 samples, validate on 180 samples
# Epoch 1/5
#  - 64s - loss: 0.4173 - iou: 0.3787 - dice_coef: 0.5425 - recall: 0.6488 - precision: 0.7497 - accuracy: 0.8291 - val_loss: 0.9555 - val_iou: 0.4512 - val_dice_coef: 0.6160 - val_recall: 0.8982 - val_precision: 0.5086 - val_accuracy: 0.7186
# Epoch 2/5
#  - 59s - loss: 0.3344 - iou: 0.4537 - dice_coef: 0.6191 - recall: 0.6899 - precision: 0.8251 - accuracy: 0.8716 - val_loss: 1.1964 - val_iou: 0.4192 - val_dice_coef: 0.5835 - val_recall: 0.9139 - val_precision: 0.4607 - val_accuracy: 0.6711
# Epoch 3/5
#  - 59s - loss: 0.3203 - iou: 0.4681 - dice_coef: 0.6330 - recall: 0.6917 - precision: 0.8411 - accuracy: 0.8759 - val_loss: 0.3597 - val_iou: 0.5446 - val_dice_coef: 0.6972 - val_recall: 0.6524 - val_precision: 0.9233 - val_accuracy: 0.8791
# Epoch 4/5
#  - 59s - loss: 0.3043 - iou: 0.4911 - dice_coef: 0.6542 - recall: 0.7149 - precision: 0.8467 - accuracy: 0.8823 - val_loss: 0.3093 - val_iou: 0.5744 - val_dice_coef: 0.7233 - val_recall: 0.6964 - val_precision: 0.9035 - val_accuracy: 0.8843
# Epoch 5/5
#  - 59s - loss: 0.2885 - iou: 0.5078 - dice_coef: 0.6696 - recall: 0.7264 - precision: 0.8516 - accuracy: 0.8869 - val_loss: 0.2936 - val_iou: 0.5370 - val_dice_coef: 0.6936 - val_recall: 0.6136 - val_precision: 0.9603 - val_accuracy: 0.8768

# %% [markdown]
# <font color='red'>**Problems In Guided Dropout Implementation**
#
# - The entire network architecture is implemented using Keras.
# - Now to implement the Guided Dropout Layer using Keras we have to know the detailed backend of the Keras Library because:
# - We should know in what form the inputs will be coming to our layer so we could manipulate them.
# - We should also know in what form the output should be given to the next layer.
# - If we implement Guided Dropout from scratch then we will have to implement entire architecture from scratch which will be neither efficient nor easily feasible.</font>

# %% [markdown]
# ### For 5 epoch

# %% [markdown]
# Here we can load a pretrained model

# %%
dropout_val=0.50
#if K.image_dim_ordering() == 'th':
if K.common.image_dim_ordering() == 'th':
    inputs = Input((I_C, 224, 224))
    #inputs = Input((INPUT_CHANNELS, 320, 320))
    axis = 1
else:
    inputs = Input((224, 224, I_C))
    #inputs = Input((320, 320, INPUT_CHANNELS))
    axis = 3
filters = 32


conv_224 = double_conv_layer(inputs, filters)
pool_112 = MaxPooling2D(pool_size=(2, 2))(conv_224)

conv_112 = double_conv_layer(pool_112, 2*filters)
pool_56 = MaxPooling2D(pool_size=(2, 2))(conv_112)

conv_56 = double_conv_layer(pool_56, 4*filters)
pool_28 = MaxPooling2D(pool_size=(2, 2))(conv_56)

conv_28 = double_conv_layer(pool_28, 8*filters)
pool_14 = MaxPooling2D(pool_size=(2, 2))(conv_28)

conv_14 = double_conv_layer(pool_14, 16*filters)
pool_7 = MaxPooling2D(pool_size=(2, 2))(conv_14)

conv_7 = double_conv_layer(pool_7, 32*filters)

up_14 = concatenate([UpSampling2D(size=(2, 2))(conv_7), conv_14], axis=axis)
up_conv_14 = double_conv_layer(up_14, 16*filters)

up_28 = concatenate([UpSampling2D(size=(2, 2))(up_conv_14), conv_28], axis=axis)
up_conv_28 = double_conv_layer(up_28, 8*filters)

up_56 = concatenate([UpSampling2D(size=(2, 2))(up_conv_28), conv_56], axis=axis)
up_conv_56 = double_conv_layer(up_56, 4*filters)

up_112 = concatenate([UpSampling2D(size=(2, 2))(up_conv_56), conv_112], axis=axis)
up_conv_112 = double_conv_layer(up_112, 2*filters)

up_224 = concatenate([UpSampling2D(size=(2, 2))(up_conv_112), conv_224], axis=axis)
up_conv_224 = double_conv_layer(up_224, filters, dropout_val)

conv_final = Conv2D(O_C, (1, 1))(up_conv_224)
conv_final = Activation('sigmoid')(conv_final)
pred = Reshape((224,224))(conv_final)
#pred = Reshape((320,320))(conv_final)

# %% [markdown]
# ## Loading the Model

# %%
model_0 = Model(inputs, pred, name="UNET_224")
model_0.compile(optimizer= Adam(lr = 0.003), loss= ['binary_crossentropy']
                  , metrics=[iou, dice_coef, recall,precision, accuracy])

# %%
model_0.load_weights('unet_5_epoch.h5')

# %%
print('\n~~~~~~~~~~~~~~~Stats after 5 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
#res = model_0.evaluate(x_train, y_train, batch_size= 18)
res = model_0.evaluate(x_train1, y_train1, batch_size=5)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
#res = model_0.evaluate(x_test, y_test, batch_size= 18)
res = model_0.evaluate(x_test, y_test, batch_size= 5)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
#res = model_0.evaluate(x_val, y_val, batch_size= 18)
res = model_0.evaluate(x_val, y_val, batch_size=5)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 5 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 2160/2160 [==============================] - 17s 8ms/step
# ________________________
# IOU:       |   53.22  |
# Dice Coef: |   68.91  |
# Precision: |   61.57  |
# Recall:    |   95.17  |
# Accuracy:  |   88.30  |
# Loss:      |   27.53  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 379/379 [==============================] - 3s 7ms/step
# ________________________
# IOU:       |   50.82  |
# Dice Coef: |   66.31  |
# Precision: |   59.97  |
# Recall:    |   93.83  |
# Accuracy:  |   87.11  |
# Loss:      |   30.30  |
# ________________________
#
# -------------On validation Set---------------------
#
# 180/180 [==============================] - 1s 7ms/step
# ________________________
# IOU:       |   53.70  |
# Dice Coef: |   69.36  |
# Precision: |   61.36  |
# Recall:    |   96.03  |
# Accuracy:  |   87.68  |
# Loss:      |   29.36  |
# ________________________

# %% [markdown]
# #### After 150 epochs

# %%
model, hist = UNET_224(epochs_num= 150, savename= 'unet_150_epoch.h5')
# Out:
# Train on 2160 samples, validate on 180 samples
# Epoch 1/150
#  - 65s - loss: 0.3940 - iou: 0.4041 - dice_coef: 0.5690 - recall: 0.6391 - precision: 0.7768 - accuracy: 0.8452 - val_loss: 0.4237 - val_iou: 0.5143 - val_dice_coef: 0.6733 - val_recall: 0.6491 - val_precision: 0.7959 - val_accuracy: 0.8471
# Epoch 2/150
#  - 59s - loss: 0.3295 - iou: 0.4568 - dice_coef: 0.6224 - recall: 0.6749 - precision: 0.8412 - accuracy: 0.8731 - val_loss: 0.3559 - val_iou: 0.4780 - val_dice_coef: 0.6391 - val_recall: 0.5293 - val_precision: 0.9795 - val_accuracy: 0.8545
# Epoch 3/150
#  - 58s - loss: 0.3077 - iou: 0.4909 - dice_coef: 0.6543 - recall: 0.7162 - precision: 0.8441 - accuracy: 0.8821 - val_loss: 0.2695 - val_iou: 0.5271 - val_dice_coef: 0.6867 - val_recall: 0.7734 - val_precision: 0.8645 - val_accuracy: 0.8958
# Epoch 4/150
#  - 58s - loss: 0.2922 - iou: 0.5069 - dice_coef: 0.6687 - recall: 0.7335 - precision: 0.8548 - accuracy: 0.8896 - val_loss: 0.2499 - val_iou: 0.5905 - val_dice_coef: 0.7385 - val_recall: 0.7723 - val_precision: 0.8874 - val_accuracy: 0.9025
# Epoch 5/150
#  - 58s - loss: 0.2715 - iou: 0.5349 - dice_coef: 0.6930 - recall: 0.7567 - precision: 0.8694 - accuracy: 0.8973 - val_loss: 0.2480 - val_iou: 0.5894 - val_dice_coef: 0.7376 - val_recall: 0.7982 - val_precision: 0.8596 - val_accuracy: 0.9003
# Epoch 6/150
#  - 58s - loss: 0.2501 - iou: 0.5615 - dice_coef: 0.7158 - recall: 0.7712 - precision: 0.8798 - accuracy: 0.9043 - val_loss: 0.2239 - val_iou: 0.6216 - val_dice_coef: 0.7622 - val_recall: 0.7779 - val_precision: 0.9022 - val_accuracy: 0.9076
# Epoch 7/150
#  - 58s - loss: 0.2410 - iou: 0.5760 - dice_coef: 0.7272 - recall: 0.7847 - precision: 0.8820 - accuracy: 0.9083 - val_loss: 0.2546 - val_iou: 0.6260 - val_dice_coef: 0.7657 - val_recall: 0.7224 - val_precision: 0.9418 - val_accuracy: 0.9039
# Epoch 8/150
#  - 58s - loss: 0.2337 - iou: 0.5827 - dice_coef: 0.7323 - recall: 0.7846 - precision: 0.8867 - accuracy: 0.9104 - val_loss: 0.1734 - val_iou: 0.6762 - val_dice_coef: 0.8058 - val_recall: 0.8768 - val_precision: 0.8885 - val_accuracy: 0.9308
# Epoch 9/150
#  - 58s - loss: 0.2154 - iou: 0.6064 - dice_coef: 0.7520 - recall: 0.8036 - precision: 0.8900 - accuracy: 0.9167 - val_loss: 0.1777 - val_iou: 0.7130 - val_dice_coef: 0.8299 - val_recall: 0.8196 - val_precision: 0.9437 - val_accuracy: 0.9322
# Epoch 10/150
#  - 58s - loss: 0.1994 - iou: 0.6324 - dice_coef: 0.7718 - recall: 0.8213 - precision: 0.8949 - accuracy: 0.9232 - val_loss: 0.1657 - val_iou: 0.6969 - val_dice_coef: 0.8194 - val_recall: 0.8809 - val_precision: 0.8968 - val_accuracy: 0.9361
# Epoch 11/150
#  - 58s - loss: 0.1884 - iou: 0.6488 - dice_coef: 0.7843 - recall: 0.8297 - precision: 0.9016 - accuracy: 0.9279 - val_loss: 0.1901 - val_iou: 0.6656 - val_dice_coef: 0.7978 - val_recall: 0.8199 - val_precision: 0.9231 - val_accuracy: 0.9257
# Epoch 12/150
#  - 58s - loss: 0.1850 - iou: 0.6557 - dice_coef: 0.7894 - recall: 0.8322 - precision: 0.9032 - accuracy: 0.9290 - val_loss: 0.1574 - val_iou: 0.7045 - val_dice_coef: 0.8254 - val_recall: 0.8864 - val_precision: 0.9008 - val_accuracy: 0.9380
# Epoch 13/150
#  - 58s - loss: 0.1826 - iou: 0.6574 - dice_coef: 0.7906 - recall: 0.8331 - precision: 0.9016 - accuracy: 0.9289 - val_loss: 0.1579 - val_iou: 0.7108 - val_dice_coef: 0.8297 - val_recall: 0.8342 - val_precision: 0.9497 - val_accuracy: 0.9357
# Epoch 14/150
#  - 58s - loss: 0.1728 - iou: 0.6714 - dice_coef: 0.8007 - recall: 0.8422 - precision: 0.9061 - accuracy: 0.9332 - val_loss: 0.1659 - val_iou: 0.6889 - val_dice_coef: 0.8144 - val_recall: 0.8102 - val_precision: 0.9481 - val_accuracy: 0.9304
# Epoch 15/150
#  - 58s - loss: 0.0778 - iou: 0.8294 - dice_coef: 0.9063 - recall: 0.9272 - precision: 0.9477 - accuracy: 0.9682 - val_loss: 0.1499 - val_iou: 0.8085 - val_dice_coef: 0.8932 - val_recall: 0.9105 - val_precision: 0.9249 - val_accuracy: 0.9519
# Epoch 54/150
#  - 58s - loss: 0.0782 - iou: 0.8288 - dice_coef: 0.9060 - recall: 0.9280 - precision: 0.9460 - accuracy: 0.9678 - val_loss: 0.1636 - val_iou: 0.7972 - val_dice_coef: 0.8861 - val_recall: 0.9077 - val_precision: 0.9141 - val_accuracy: 0.9478
# Epoch 55/150
#  - 58s - loss: 0.0759 - iou: 0.8323 - dice_coef: 0.9080 - recall: 0.9291 - precision: 0.9471 - accuracy: 0.9688 - val_loss: 0.1581 - val_iou: 0.8069 - val_dice_coef: 0.8922 - val_recall: 0.9179 - val_precision: 0.9107 - val_accuracy: 0.9493
# Epoch 56/150
#  - 58s - loss: 0.0728 - iou: 0.8365 - dice_coef: 0.9105 - recall: 0.9303 - precision: 0.9492 - accuracy: 0.9699 - val_loss: 0.1683 - val_iou: 0.7887 - val_dice_coef: 0.8808 - val_recall: 0.9167 - val_precision: 0.9020 - val_accuracy: 0.9463
# Epoch 57/150
#  - 58s - loss: 0.0715 - iou: 0.8392 - dice_coef: 0.9121 - recall: 0.9316 - precision: 0.9497 - accuracy: 0.9704 - val_loss: 0.1579 - val_iou: 0.8008 - val_dice_coef: 0.8883 - val_recall: 0.8995 - val_precision: 0.9263 - val_accuracy: 0.9489
# Epoch 58/150
#  - 58s - loss: 0.0731 - iou: 0.8385 - dice_coef: 0.9116 - recall: 0.9317 - precision: 0.9506 - accuracy: 0.9703 - val_loss: 0.1593 - val_iou: 0.8070 - val_dice_coef: 0.8922 - val_recall: 0.9162 - val_precision: 0.9120 - val_accuracy: 0.9494
# Epoch 59/150
#  - 58s - loss: 0.0674 - iou: 0.8475 - dice_coef: 0.9170 - recall: 0.9361 - precision: 0.9526 - accuracy: 0.9720 - val_loss: 0.1805 - val_iou: 0.8046 - val_dice_coef: 0.8908 - val_recall: 0.9087 - val_precision: 0.9147 - val_accuracy: 0.9480
# Epoch 60/150
#  - 58s - loss: 0.0663 - iou: 0.8500 - dice_coef: 0.9185 - recall: 0.9370 - precision: 0.9531 - accuracy: 0.9726 - val_loss: 0.1863 - val_iou: 0.8003 - val_dice_coef: 0.8878 - val_recall: 0.9113 - val_precision: 0.9041 - val_accuracy: 0.9456
# Epoch 61/150
#  - 58s - loss: 0.0671 - iou: 0.8481 - dice_coef: 0.9173 - recall: 0.9367 - precision: 0.9523 - accuracy: 0.9724 - val_loss: 0.2049 - val_iou: 0.7922 - val_dice_coef: 0.8827 - val_recall: 0.8701 - val_precision: 0.9400 - val_accuracy: 0.9442
# Epoch 62/150
#  - 58s - loss: 0.0690 - iou: 0.8468 - dice_coef: 0.9167 - recall: 0.9372 - precision: 0.9523 - accuracy: 0.9719 - val_loss: 0.1750 - val_iou: 0.8090 - val_dice_coef: 0.8934 - val_recall: 0.9292 - val_precision: 0.8925 - val_accuracy: 0.9469
# Epoch 82/150
#  - 58s - loss: 0.0465 - iou: 0.8918 - dice_coef: 0.9426 - recall: 0.9573 - precision: 0.9656 - accuracy: 0.9807 - val_loss: 0.2299 - val_iou: 0.8165 - val_dice_coef: 0.8976 - val_recall: 0.8921 - val_precision: 0.9293 - val_accuracy: 0.9477
# Epoch 83/150
#  - 58s - loss: 0.0456 - iou: 0.8935 - dice_coef: 0.9435 - recall: 0.9588 - precision: 0.9650 - accuracy: 0.9811 - val_loss: 0.2225 - val_iou: 0.8159 - val_dice_coef: 0.8974 - val_recall: 0.9102 - val_precision: 0.9097 - val_accuracy: 0.9467
# Epoch 84/150
#  - 58s - loss: 0.0465 - iou: 0.8920 - dice_coef: 0.9427 - recall: 0.9579 - precision: 0.9656 - accuracy: 0.9810 - val_loss: 0.2414 - val_iou: 0.8111 - val_dice_coef: 0.8945 - val_recall: 0.8974 - val_precision: 0.9191 - val_accuracy: 0.9460
# Epoch 85/150
#  - 58s - loss: 0.0441 - iou: 0.8978 - dice_coef: 0.9459 - recall: 0.9613 - precision: 0.9668 - accuracy: 0.9819 - val_loss: 0.2417 - val_iou: 0.8136 - val_dice_coef: 0.8961 - val_recall: 0.9090 - val_precision: 0.9089 - val_accuracy: 0.9462
# Epoch 86/150
#  - 58s - loss: 0.0444 - iou: 0.8967 - dice_coef: 0.9454 - recall: 0.9594 - precision: 0.9670 - accuracy: 0.9817 - val_loss: 0.2387 - val_iou: 0.8140 - val_dice_coef: 0.8962 - val_recall: 0.8924 - val_precision: 0.9263 - val_accuracy: 0.9465
# Epoch 87/150
#  - 58s - loss: 0.0474 - iou: 0.8903 - dice_coef: 0.9416 - recall: 0.9581 - precision: 0.9640 - accuracy: 0.9807 - val_loss: 0.2251 - val_iou: 0.8109 - val_dice_coef: 0.8936 - val_recall: 0.9020 - val_precision: 0.9128 - val_accuracy: 0.9447
# Epoch 88/150
#  - 58s - loss: 0.0428 - iou: 0.9004 - dice_coef: 0.9474 - recall: 0.9620 - precision: 0.9675 - accuracy: 0.9823 - val_loss: 0.2167 - val_iou: 0.8206 - val_dice_coef: 0.9002 - val_recall: 0.9091 - val_precision: 0.9145 - val_accuracy: 0.9482
# Epoch 89/150
#  - 58s - loss: 0.0414 - iou: 0.9019 - dice_coef: 0.9482 - recall: 0.9625 - precision: 0.9672 - accuracy: 0.9827 - val_loss: 0.2306 - val_iou: 0.8220 - val_dice_coef: 0.9013 - val_recall: 0.9104 - val_precision: 0.9154 - val_accuracy: 0.9487
# Epoch 90/150
#  - 58s - loss: 0.0419 - iou: 0.9031 - dice_coef: 0.9489 - recall: 0.9628 - precision: 0.9684 - accuracy: 0.9828 - val_loss: 0.2512 - val_iou: 0.8130 - val_dice_coef: 0.8958 - val_recall: 0.9125 - val_precision: 0.9020 - val_accuracy: 0.9451
# Epoch 91/150
# Epoch 101/150
#  - 58s - loss: 0.0353 - iou: 0.9165 - dice_coef: 0.9564 - recall: 0.9683 - precision: 0.9724 - accuracy: 0.9852 - val_loss: 0.2581 - val_iou: 0.8253 - val_dice_coef: 0.9032 - val_recall: 0.9056 - val_precision: 0.9207 - val_accuracy: 0.9491
# Epoch 102/150
#  - 58s - loss: 0.0375 - iou: 0.9122 - dice_coef: 0.9536 - recall: 0.9673 - precision: 0.9703 - accuracy: 0.9846 - val_loss: 0.2486 - val_iou: 0.8284 - val_dice_coef: 0.9051 - val_recall: 0.9131 - val_precision: 0.9173 - val_accuracy: 0.9503
# Epoch 103/150
#  - 58s - loss: 0.0374 - iou: 0.9125 - dice_coef: 0.9541 - recall: 0.9682 - precision: 0.9700 - accuracy: 0.9847 - val_loss: 0.4228 - val_iou: 0.7780 - val_dice_coef: 0.8721 - val_recall: 0.8253 - val_precision: 0.9587 - val_accuracy: 0.9347
# Epoch 104/150
#  - 58s - loss: 0.0379 - iou: 0.9103 - dice_coef: 0.9529 - recall: 0.9671 - precision: 0.9700 - accuracy: 0.9845 - val_loss: 0.2520 - val_iou: 0.8230 - val_dice_coef: 0.9015 - val_recall: 0.9022 - val_precision: 0.9230 - val_accuracy: 0.9487
# Epoch 105/150
#  - 58s - loss: 0.0348 - iou: 0.9176 - dice_coef: 0.9569 - recall: 0.9701 - precision: 0.9720 - accuracy: 0.9856 - val_loss: 0.2574 - val_iou: 0.8236 - val_dice_coef: 0.9022 - val_recall: 0.9118 - val_precision: 0.9121 - val_accuracy: 0.9483
# Epoch 106/150
#  - 58s - loss: 0.0343 - iou: 0.9189 - dice_coef: 0.9576 - recall: 0.9709 - precision: 0.9722 - accuracy: 0.9858 - val_loss: 0.2625 - val_iou: 0.8280 - val_dice_coef: 0.9046 - val_recall: 0.9076 - val_precision: 0.9207 - val_accuracy: 0.9498
# Epoch 107/150
#  - 59s - loss: 0.0348 - iou: 0.9175 - dice_coef: 0.9567 - recall: 0.9707 - precision: 0.9712 - accuracy: 0.9857 - val_loss: 0.2352 - val_iou: 0.8305 - val_dice_coef: 0.9063 - val_recall: 0.9131 - val_precision: 0.9172 - val_accuracy: 0.9506
# Epoch 108/150
#  - 58s - loss: 0.0329 - iou: 0.9221 - dice_coef: 0.9594 - recall: 0.9716 - precision: 0.9734 - accuracy: 0.9863 - val_loss: 0.2575 - val_iou: 0.8290 - val_dice_coef: 0.9053 - val_recall: 0.9076 - val_precision: 0.9212 - val_accuracy: 0.9501
# Epoch 109/150
#  - 58s - loss: 0.0367 - iou: 0.9146 - dice_coef: 0.9552 - recall: 0.9691 - precision: 0.9711 - accuracy: 0.9851 - val_loss: 0.2605 - val_iou: 0.8227 - val_dice_coef: 0.9012 - val_recall: 0.8985 - val_precision: 0.9253 - val_accuracy: 0.9484
# Epoch 110/150
#  - 58s - loss: 0.0331 - iou: 0.9215 - dice_coef: 0.9590 - recall: 0.9711 - precision: 0.9739 - accuracy: 0.9863 - val_loss: 0.2548 - val_iou: 0.8257 - val_dice_coef: 0.9034 - val_recall: 0.9171 - val_precision: 0.9080 - val_accuracy: 0.9487
# Epoch 111/150
#  - 58s - loss: 0.0323 - iou: 0.9236 - dice_coef: 0.9602 - recall: 0.9723 - precision: 0.9742 - accuracy: 0.9867 - val_loss: 0.2819 - val_iou: 0.8266 - val_dice_coef: 0.9038 - val_recall: 0.9226 - val_precision: 0.8997 - val_accuracy: 0.9476
# Epoch 112/150
#  - 58s - loss: 0.0317 - iou: 0.9252 - dice_coef: 0.9611 - recall: 0.9731 - precision: 0.9743 - accuracy: 0.9868 - val_loss: 0.2646 - val_iou: 0.8315 - val_dice_coef: 0.9068 - val_recall: 0.9147 - val_precision: 0.9154 - val_accuracy: 0.9502
# Epoch 113/150
#  - 58s - loss: 0.0313 - iou: 0.9259 - dice_coef: 0.9614 - recall: 0.9728 - precision: 0.9752 - accuracy: 0.9870 - val_loss: 0.3061 - val_iou: 0.8283 - val_dice_coef: 0.9048 - val_recall: 0.9154 - val_precision: 0.9096 - val_accuracy: 0.9485
# Epoch 114/150
#  - 58s - loss: 0.0322 - iou: 0.9233 - dice_coef: 0.9600 - recall: 0.9717 - precision: 0.9742 - accuracy: 0.9867 - val_loss: 0.3068 - val_iou: 0.8210 - val_dice_coef: 0.9000 - val_recall: 0.9059 - val_precision: 0.9119 - val_accuracy: 0.9462
# Epoch 115/150
#  - 58s - loss: 0.0318 - iou: 0.9245 - dice_coef: 0.9607 - recall: 0.9722 - precision: 0.9745 - accuracy: 0.9866 - val_loss: 0.2831 - val_iou: 0.8263 - val_dice_coef: 0.9034 - val_recall: 0.9055 - val_precision: 0.9192 - val_accuracy: 0.9486
# Epoch 116/150
#  - 58s - loss: 0.0311 - iou: 0.9263 - dice_coef: 0.9617 - recall: 0.9737 - precision: 0.9744 - accuracy: 0.9871 - val_loss: 0.2916 - val_iou: 0.8268 - val_dice_coef: 0.9040 - val_recall: 0.9042 - val_precision: 0.9209 - val_accuracy: 0.9486
# Epoch 117/150
#  - 58s - loss: 0.0316 - iou: 0.9253 - dice_coef: 0.9611 - recall: 0.9732 - precision: 0.9740 - accuracy: 0.9869 - val_loss: 0.2625 - val_iou: 0.8256 - val_dice_coef: 0.9033 - val_recall: 0.9096 - val_precision: 0.9147 - val_accuracy: 0.9483
# Epoch 118/150
#  - 58s - loss: 0.0311 - iou: 0.9256 - dice_coef: 0.9612 - recall: 0.9737 - precision: 0.9742 - accuracy: 0.9871 - val_loss: 0.3045 - val_iou: 0.8294 - val_dice_coef: 0.9054 - val_recall: 0.9022 - val_precision: 0.9256 - val_accuracy: 0.9493
# Epoch 119/150
#  - 58s - loss: 0.0306 - iou: 0.9268 - dice_coef: 0.9619 - recall: 0.9733 - precision: 0.9754 - accuracy: 0.9873 - val_loss: 0.2902 - val_iou: 0.8290 - val_dice_coef: 0.9053 - val_recall: 0.9144 - val_precision: 0.9115 - val_accuracy: 0.9486
# Epoch 120/150
#  - 58s - loss: 0.0300 - iou: 0.9285 - dice_coef: 0.9628 - recall: 0.9741 - precision: 0.9754 - accuracy: 0.9874 - val_loss: 0.3019 - val_iou: 0.8293 - val_dice_coef: 0.9053 - val_recall: 0.9017 - val_precision: 0.9256 - val_accuracy: 0.9496
# Epoch 121/150
#  - 58s - loss: 0.0295 - iou: 0.9299 - dice_coef: 0.9636 - recall: 0.9747 - precision: 0.9764 - accuracy: 0.9878 - val_loss: 0.2874 - val_iou: 0.8297 - val_dice_coef: 0.9058 - val_recall: 0.9120 - val_precision: 0.9145 - val_accuracy: 0.9492
# Epoch 122/150
#  - 58s - loss: 0.0295 - iou: 0.9293 - dice_coef: 0.9633 - recall: 0.9742 - precision: 0.9762 - accuracy: 0.9878 - val_loss: 0.2734 - val_iou: 0.8284 - val_dice_coef: 0.9052 - val_recall: 0.9091 - val_precision: 0.9174 - val_accuracy: 0.9490
# Epoch 123/150
#  - 58s - loss: 0.0294 - iou: 0.9296 - dice_coef: 0.9634 - recall: 0.9752 - precision: 0.9753 - accuracy: 0.9879 - val_loss: 0.2911 - val_iou: 0.8306 - val_dice_coef: 0.9062 - val_recall: 0.9176 - val_precision: 0.9095 - val_accuracy: 0.9494
# Epoch 124/150
#  - 58s - loss: 0.0412 - iou: 0.9101 - dice_coef: 0.9527 - recall: 0.9668 - precision: 0.9700 - accuracy: 0.9842 - val_loss: 0.2322 - val_iou: 0.8244 - val_dice_coef: 0.9024 - val_recall: 0.9068 - val_precision: 0.9184 - val_accuracy: 0.9488
# Epoch 125/150
#  - 58s - loss: 0.0318 - iou: 0.9242 - dice_coef: 0.9605 - recall: 0.9724 - precision: 0.9742 - accuracy: 0.9867 - val_loss: 0.2910 - val_iou: 0.8262 - val_dice_coef: 0.9033 - val_recall: 0.8988 - val_precision: 0.9246 - val_accuracy: 0.9483
# Epoch 126/150
#  - 58s - loss: 0.0307 - iou: 0.9266 - dice_coef: 0.9618 - recall: 0.9741 - precision: 0.9745 - accuracy: 0.9873 - val_loss: 0.2686 - val_iou: 0.8203 - val_dice_coef: 0.8997 - val_recall: 0.8916 - val_precision: 0.9276 - val_accuracy: 0.9478
# Epoch 127/150
#  - 58s - loss: 0.0297 - iou: 0.9296 - dice_coef: 0.9634 - recall: 0.9748 - precision: 0.9761 - accuracy: 0.9877 - val_loss: 0.2690 - val_iou: 0.8315 - val_dice_coef: 0.9069 - val_recall: 0.9135 - val_precision: 0.9162 - val_accuracy: 0.9500
# Epoch 128/150
#  - 58s - loss: 0.0282 - iou: 0.9332 - dice_coef: 0.9654 - recall: 0.9768 - precision: 0.9765 - accuracy: 0.9883 - val_loss: 0.2836 - val_iou: 0.8331 - val_dice_coef: 0.9078 - val_recall: 0.9135 - val_precision: 0.9161 - val_accuracy: 0.9500
# Epoch 129/150
#  - 58s - loss: 0.0283 - iou: 0.9320 - dice_coef: 0.9647 - recall: 0.9768 - precision: 0.9764 - accuracy: 0.9884 - val_loss: 0.2893 - val_iou: 0.8307 - val_dice_coef: 0.9064 - val_recall: 0.9017 - val_precision: 0.9255 - val_accuracy: 0.9494
# Epoch 130/150
#  - 58s - loss: 0.0272 - iou: 0.9356 - dice_coef: 0.9667 - recall: 0.9773 - precision: 0.9775 - accuracy: 0.9887 - val_loss: 0.2876 - val_iou: 0.8304 - val_dice_coef: 0.9062 - val_recall: 0.9132 - val_precision: 0.9140 - val_accuracy: 0.9493
# Epoch 131/150
#  - 58s - loss: 0.0275 - iou: 0.9342 - dice_coef: 0.9659 - recall: 0.9771 - precision: 0.9767 - accuracy: 0.9886 - val_loss: 0.2922 - val_iou: 0.8282 - val_dice_coef: 0.9049 - val_recall: 0.9234 - val_precision: 0.9008 - val_accuracy: 0.9480
# Epoch 132/150
#  - 59s - loss: 0.0271 - iou: 0.9351 - dice_coef: 0.9664 - recall: 0.9781 - precision: 0.9767 - accuracy: 0.9888 - val_loss: 0.3061 - val_iou: 0.8308 - val_dice_coef: 0.9063 - val_recall: 0.8987 - val_precision: 0.9297 - val_accuracy: 0.9496
# Epoch 133/150
#  - 58s - loss: 0.0270 - iou: 0.9356 - dice_coef: 0.9667 - recall: 0.9773 - precision: 0.9778 - accuracy: 0.9888 - val_loss: 0.2946 - val_iou: 0.8294 - val_dice_coef: 0.9053 - val_recall: 0.9068 - val_precision: 0.9198 - val_accuracy: 0.9489
# Epoch 134/150
#  - 58s - loss: 0.0265 - iou: 0.9363 - dice_coef: 0.9671 - recall: 0.9783 - precision: 0.9767 - accuracy: 0.9889 - val_loss: 0.2886 - val_iou: 0.8307 - val_dice_coef: 0.9063 - val_recall: 0.9153 - val_precision: 0.9125 - val_accuracy: 0.9496
# Epoch 135/150
#  - 58s - loss: 0.0264 - iou: 0.9374 - dice_coef: 0.9676 - recall: 0.9776 - precision: 0.9786 - accuracy: 0.9891 - val_loss: 0.3053 - val_iou: 0.8322 - val_dice_coef: 0.9072 - val_recall: 0.8998 - val_precision: 0.9301 - val_accuracy: 0.9504
# Epoch 136/150
#  - 58s - loss: 0.0265 - iou: 0.9361 - dice_coef: 0.9669 - recall: 0.9776 - precision: 0.9778 - accuracy: 0.9890 - val_loss: 0.2986 - val_iou: 0.8344 - val_dice_coef: 0.9083 - val_recall: 0.9105 - val_precision: 0.9202 - val_accuracy: 0.9505
# Epoch 137/150
#  - 58s - loss: 0.0265 - iou: 0.9361 - dice_coef: 0.9669 - recall: 0.9776 - precision: 0.9777 - accuracy: 0.9890 - val_loss: 0.3021 - val_iou: 0.8352 - val_dice_coef: 0.9090 - val_recall: 0.9114 - val_precision: 0.9201 - val_accuracy: 0.9507
# Epoch 138/150
#  - 58s - loss: 0.0262 - iou: 0.9374 - dice_coef: 0.9676 - recall: 0.9779 - precision: 0.9785 - accuracy: 0.9891 - val_loss: 0.2898 - val_iou: 0.8302 - val_dice_coef: 0.9060 - val_recall: 0.9007 - val_precision: 0.9271 - val_accuracy: 0.9496
# Epoch 139/150
#  - 59s - loss: 0.0254 - iou: 0.9389 - dice_coef: 0.9684 - recall: 0.9785 - precision: 0.9786 - accuracy: 0.9894 - val_loss: 0.3231 - val_iou: 0.8306 - val_dice_coef: 0.9062 - val_recall: 0.8954 - val_precision: 0.9321 - val_accuracy: 0.9493
# Epoch 140/150
#  - 58s - loss: 0.0259 - iou: 0.9381 - dice_coef: 0.9680 - recall: 0.9788 - precision: 0.9779 - accuracy: 0.9893 - val_loss: 0.3286 - val_iou: 0.8305 - val_dice_coef: 0.9059 - val_recall: 0.8993 - val_precision: 0.9285 - val_accuracy: 0.9493
# Epoch 141/150
#  - 58s - loss: 0.0264 - iou: 0.9369 - dice_coef: 0.9673 - recall: 0.9776 - precision: 0.9785 - accuracy: 0.9891 - val_loss: 0.3019 - val_iou: 0.8290 - val_dice_coef: 0.9051 - val_recall: 0.9008 - val_precision: 0.9239 - val_accuracy: 0.9485
# Epoch 142/150
#  - 58s - loss: 0.0350 - iou: 0.9236 - dice_coef: 0.9601 - recall: 0.9731 - precision: 0.9737 - accuracy: 0.9864 - val_loss: 0.2508 - val_iou: 0.8088 - val_dice_coef: 0.8927 - val_recall: 0.9150 - val_precision: 0.8959 - val_accuracy: 0.9440
# Epoch 143/150
#  - 58s - loss: 0.0319 - iou: 0.9259 - dice_coef: 0.9613 - recall: 0.9733 - precision: 0.9752 - accuracy: 0.9873 - val_loss: 0.2656 - val_iou: 0.8263 - val_dice_coef: 0.9033 - val_recall: 0.9096 - val_precision: 0.9161 - val_accuracy: 0.9485
# Epoch 144/150
#  - 58s - loss: 0.0269 - iou: 0.9356 - dice_coef: 0.9666 - recall: 0.9762 - precision: 0.9787 - accuracy: 0.9889 - val_loss: 0.2999 - val_iou: 0.8299 - val_dice_coef: 0.9056 - val_recall: 0.9107 - val_precision: 0.9166 - val_accuracy: 0.9489
# Epoch 145/150
#  - 58s - loss: 0.0257 - iou: 0.9383 - dice_coef: 0.9681 - recall: 0.9786 - precision: 0.9784 - accuracy: 0.9893 - val_loss: 0.2921 - val_iou: 0.8284 - val_dice_coef: 0.9048 - val_recall: 0.9125 - val_precision: 0.9122 - val_accuracy: 0.9484
# Epoch 146/150
#  - 58s - loss: 0.0252 - iou: 0.9394 - dice_coef: 0.9687 - recall: 0.9778 - precision: 0.9797 - accuracy: 0.9895 - val_loss: 0.3141 - val_iou: 0.8283 - val_dice_coef: 0.9048 - val_recall: 0.9087 - val_precision: 0.9154 - val_accuracy: 0.9482
# Epoch 147/150
#  - 58s - loss: 0.0249 - iou: 0.9404 - dice_coef: 0.9692 - recall: 0.9786 - precision: 0.9800 - accuracy: 0.9897 - val_loss: 0.3326 - val_iou: 0.8329 - val_dice_coef: 0.9075 - val_recall: 0.9075 - val_precision: 0.9201 - val_accuracy: 0.9492
# Epoch 148/150
#  - 59s - loss: 0.0253 - iou: 0.9398 - dice_coef: 0.9689 - recall: 0.9779 - precision: 0.9800 - accuracy: 0.9895 - val_loss: 0.2795 - val_iou: 0.8286 - val_dice_coef: 0.9049 - val_recall: 0.9094 - val_precision: 0.9166 - val_accuracy: 0.9486
# Epoch 149/150
#  - 58s - loss: 0.0243 - iou: 0.9418 - dice_coef: 0.9700 - recall: 0.9789 - precision: 0.9804 - accuracy: 0.9899 - val_loss: 0.3126 - val_iou: 0.8310 - val_dice_coef: 0.9062 - val_recall: 0.9021 - val_precision: 0.9256 - val_accuracy: 0.9491
# Epoch 150/150
#  - 58s - loss: 0.0239 - iou: 0.9415 - dice_coef: 0.9698 - recall: 0.9792 - precision: 0.9799 - accuracy: 0.9900 - val_loss: 0.3159 - val_iou: 0.8279 - val_dice_coef: 0.9044 - val_recall: 0.9061 - val_precision: 0.9174 - val_accuracy: 0.9480

# %%
model_1 = Model(inputs, pred, name="UNET_224")
model_1.compile(optimizer= Adam(lr = 0.003), loss= ['binary_crossentropy']
                  , metrics=[iou, dice_coef, recall,precision, accuracy])

# %%
model_1.load_weights('unet_150_epoch.h5')

# %% [markdown]
# Testing the statistics after 150 epochs

# %%
print('\n~~~~~~~~~~~~~~~Stats after 150 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
#res = model_1.evaluate(x_train, y_train, batch_size= 18)
res = model_1.evaluate(x_train1, y_train1, batch_size= 5)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Recall:    |   {:.2f}  |'.format(res[3]*100))
print('Precision: |   {:.2f}  |'.format(res[4]*100))

print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
#res = model_1.evaluate(x_test, y_test, batch_size= 18)
res = model_1.evaluate(x_test, y_test, batch_size= 5)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Recall:    |   {:.2f}  |'.format(res[3]*100))
print('Precision: |   {:.2f}  |'.format(res[4]*100))

print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
#res = model_1.evaluate(x_val, y_val, batch_size= 18)
res = model_1.evaluate(x_val, y_val, batch_size= 5)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Recall:    |   {:.2f}  |'.format(res[3]*100))
print('Precision: |   {:.2f}  |'.format(res[4]*100))

print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 150 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 2160/2160 [==============================] - 17s 8ms/step
# ________________________
# IOU:       |   95.16  |
# Dice Coef: |   97.51  |
# Recall:    |   98.94  |
# Precision: |   97.81  |
# Accuracy:  |   99.18  |
# Loss:      |   1.87  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 379/379 [==============================] - 3s 8ms/step
# ________________________
# IOU:       |   81.89  |
# Dice Coef: |   89.66  |
# Recall:    |   90.60  |
# Precision: |   90.87  |
# Accuracy:  |   94.81  |
# Loss:      |   28.56  |
# ________________________
#
# -------------On validation Set---------------------
#
# 180/180 [==============================] - 1s 8ms/step
# ________________________
# IOU:       |   82.79  |
# Dice Coef: |   90.44  |
# Recall:    |   90.61  |
# Precision: |   91.74  |
# Accuracy:  |   94.80  |
# Loss:      |   31.59  |
# ________________________

# %% [markdown]
# ### Plotting Training Stats

# %% [markdown]
# ## Visualising Predicted Lesions

# %%
plt.figure(figsize=(20, 14))
plt.suptitle('Training Statistics on Train Set')
plt.subplot(2,2,1)
plt.plot(hist.history['loss'], 'red')
plt.title('Loss')
plt.subplot(2,2,2)
plt.plot(hist.history['accuracy'], 'green')
plt.title('Accuracy')
plt.subplot(2,2,3)
plt.plot(hist.history['val_loss'], 'red')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Valdiation Loss')
plt.subplot(2,2,4)
plt.plot(hist.history['val_accuracy'], 'green')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Validation Accuracy')
plt.show()

# %% [markdown]
# We have trained the model on the **training set**.
# We will make predictions on the unseen **test set**

# %%
img_num = 49
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
#img_pred = model_1.predict(x_test[img_num].reshape(1,320,320,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224, 224), plt.cm.binary_r)
#plt.imshow(img_pred.reshape(320, 320), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 10
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
#img_pred = model_1.predict(x_test[img_num].reshape(1,320,320,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
#plt.imshow(img_pred.reshape(320,320), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 36
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
#img_pred = model_1.predict(x_test[img_num].reshape(1,320,320,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
#plt.imshow(img_pred.reshape(320,320), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 32
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
#img_pred = model_1.predict(x_test[img_num].reshape(1,320,320,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
#plt.imshow(img_pred.reshape(320,320), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 29
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
#img_pred = model_1.predict(x_test[img_num].reshape(1,320,320,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
#plt.imshow(img_pred.reshape(320,320), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 21
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
#img_pred = model_1.predict(x_test[img_num].reshape(1,320,320,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
#plt.imshow(img_pred.reshape(320,320), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %% [markdown]
# ## Final Enhance

# %% [markdown]
# * Currently the predicted outputs are blurry because the predicted pixel values are in the range 0 - 1.
# * To make clear edge preditions we can enhance our image by rounding up the pixel values to 1 which are > 0.5  .
# * While rounding down the pixel values to 0 which are < 0.5.
# * We can enhance the image to look for absolute shape predicted by ceiling and flooring the predicted values.

# %%
def enhance(img):
    sub = (model_1.predict(img.reshape(1,224,224,3))).flatten()
    #sub = (model_1.predict(img.reshape(1,320,320,3))).flatten()

    for i in range(len(sub)):
        if sub[i] > 0.5:
            sub[i] = 1
        else:
            sub[i] = 0
    return sub

# %%
plt.figure(figsize=(12,12))
plt.suptitle('Comparing the Prediction after enhancement')
plt.subplot(3,2,1)
plt.imshow(y_test[21],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,2)
plt.imshow(enhance(x_test[21]).reshape(224,224), plt.cm.binary_r)
#plt.imshow(enhance(x_test[21]).reshape(320,320), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,3)
plt.imshow(y_test[47],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,4)
plt.imshow(enhance(x_test[47]).reshape(224,224), plt.cm.binary_r)
#plt.imshow(enhance(x_test[47]).reshape(320,320), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,5)
plt.imshow(y_test[36],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,6)
plt.imshow(enhance(x_test[36]).reshape(224,224), plt.cm.binary_r)
#plt.imshow(enhance(x_test[36]).reshape(320,320), plt.cm.binary_r)
plt.title('Predicted')
plt.show()

# %%
plt.figure(figsize=(12,12))
plt.suptitle('Comparing the Prediction after enhancement')
plt.subplot(3,2,1)
plt.imshow(y_test[32],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,2)
plt.imshow(enhance(x_test[32]).reshape(224,224), plt.cm.binary_r)
#plt.imshow(enhance(x_test[21]).reshape(320,320), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,3)
plt.imshow(y_test[22],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,4)
plt.imshow(enhance(x_test[22]).reshape(224,224), plt.cm.binary_r)
#plt.imshow(enhance(x_test[47]).reshape(320,320), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,5)
plt.imshow(y_test[36],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,6)
plt.imshow(enhance(x_test[36]).reshape(224,224), plt.cm.binary_r)
#plt.imshow(enhance(x_test[36]).reshape(320,320), plt.cm.binary_r)
plt.title('Predicted')
plt.show()
